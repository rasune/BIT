# %% [markdown]
# Užduotyse naudojami list, dict, for, while, if, elif, else, break, continue, taip pat sąrašų ir žodynų
# metodai kaip pop(), remove(), reverse(), append(), items(), type().

# %% [markdown]
# 1. Sukurkite sąrašą su skaičiais nuo 1 iki 10. Panaudokite `for` ciklą ir atspausdinkite tik
# lyginius skaičius. Naudokite `continue`.

# %% [markdown]
# 1.Creat a list of numbers from 1 to 10. Use FOR cycle and print just even numbers. Use continue

# %%
numbers = list(range(1,11))

for number in numbers:
    if number %2 != 0:
        continue    #liepia ciklui praleisti likusi sios iteracijos koda ir eik prie kito elemento
    print(number)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# 2.You have a list: ['apple', 'banana', 'cherry', 'date']. Use a `for` loop and an `if` to print out the fruits name length is greater than 5.

# %%
fruits =['apple', 'banana', 'cherry', 'date']

for fruit in fruits:
   if len(fruit) > 5:
    print(fruit)
# Out:
# banana
# cherry

# %% [markdown]
# 3. Use a `while` loop to count the sum of the numbers from 1 to 20. If the sum exceeds 100, terminate the loop with `break`.

# %%
number = 1
suma = 0

while number <= 20:
    suma += number
    if suma > 100:
     break
number += 1
print("Suma:",suma)
# Out:
# Suma: 101

# %% [markdown]
# 4. You have a dictionary with student grades. Print only those students whose grade is greater than or equal to 8. Use `if` and `for`.

# %%
students = {
    "Anna": 10,
    "John": 5,
    "Paul": 9,
    "Mia": 7
}

for stu_name, stu_mark in students.items():
    print(stu_name)
    print(stu_mark)
# Out:
# Anna
# 10
# John
# 5
# Paul
# 9
# Mia
# 7

# %%
import pandas as pd

duomenys = [
    ('ID001', 'Jonas', 'Vilnius', 150.0),
    ('ID002', 'Ona', 'Kaunas', 200.0),
    ('ID003', 'Petras', 'Klaipėda', 175.0),
    ('ID004', 'Jonas', 'Vilnius', 180.0)
]
 
df = pd.DataFrame(duomenys, columns=['ID', 'Vardas', 'Miestas', 'Pardavimai'])
print(df)
 
# Kiek unikalių klientų vardų
print("Unikalūs vardai:", set(df['Vardas']))
 
# Pardavimų suma per miestus
print("Pardavimai pagal miestą:")
print(df.groupby('Miestas')['Pardavimai'].sum())
# Out:
#       ID  Vardas   Miestas  Pardavimai
# 0  ID001   Jonas   Vilnius       150.0
# 1  ID002     Ona    Kaunas       200.0
# 2  ID003  Petras  Klaipėda       175.0
# 3  ID004   Jonas   Vilnius       180.0
# Unikalūs vardai: {'Ona', 'Jonas', 'Petras'}
# Pardavimai pagal miestą:
# Miestas
# Kaunas      200.0
# Klaipėda    175.0
# Vilnius     330.0
# Name: Pardavimai, dtype: float64
