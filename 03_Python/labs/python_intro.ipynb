# %% [markdown]
# ### Tutorial

# %%
print("Hello world!")

# addition 
2+1

# Modulo 
7/4
# Out:
# Hello world!
# 1.75

# %%
# addition
2+1
# Out:
# 3

# %%
b = '123b'

# %%
type (b)
# Out:
# str

# %%
# Single word 
print("hello' 'ddd")
# Out:
# hello' 'ddd

# %%
name = input("Įveskite savo vardą: ")
print("Hello,", name )

# %%
number = int(input("Įveskite skaičių: "))
print("Įvestas skaičius padaugintas iš 2:", number * 2)
# Out:
# Įvestas skaičius padaugintas iš 2: 60

# %%
age = int(input("How old are you? "))
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Pilnametis

# %%
name = input("name: ")
miestas = input("Town: ")
print(name, "lives in the town", miestas)
# Out:
# Rasa gyvena mieste alytus

# %%
number = int(input("Enter the number: "))
if number == 0:
    print(" The number is nule")
elif number % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is even

# %%
ivestis = input("Įveskite 'taip' arba 'ne': ")
if ivestis.lower() == "taip":
    print("Pasirinkote TAIP")
elif ivestis.lower() == "ne":
    print("Pasirinkote NE")
else:
    print("Nesupratau pasirinkimo")

# %%
hours = 8
pay_per_hour = 7.5

dienos_uzdarbis = valandos * uzmokestis_uz_valanda

print("Dienos uždarbis:", dienos_uzdarbis, "€")
# Out:
# Dienos uždarbis: 60.0 €

# %%
## 2.Užduotis.Pritaikykite 15% nuolaidą prekei, kurios kaina 120$
kaina = 120
nuolaida = 0.15

galutine_kaina = kaina - (kaina * nuolaida)

print("Galutinė kaina su 15% nuolaida:", galutine_kaina, "€")
# Out:
# Galutinė kaina su 15% nuolaida: 102.0 €

# %%
## 3.Užduotis Apskaičiuokite mėnesio algą (160 val. × 12 €/val.).
valandos = 160
uzmokestis_uz_valanda = 12 

Menesio_alga = valandos * uzmokestis_uz_valanda

print("Menesinis atlyginimas:",Menesio_alga, "€")
# Out:
# Menesinis atlyginimas: 1920 €

# %%
## 4.Uzduotis.Apskaičiuokite pelną, jei savikaina 40 €, o pardavimo kaina 65 €
savikaina = 40
pardavimo_kaina = 65

pelnas = pardavimo_kaina - savikaina

print("Gaunamas pelnas:", pelnas, "€")
# Out:
# Gaunamas pelnas: 25 €

# %%
## 5.Uzduotis. Apskaičiuokite kainą be PVM (121 € su 21% PVM).
kaina_su_pvm = 121
PVM_procentai = 1.21

kaina_be_PVM = kaina_su_pvm / PVM_procentai

print("Prekes kaina be PVM:", kaina_be_PVM, "€")
# Out:
# Prekes kaina be PVM: 100.0 €

# %%
## 6.Uzduotis.Apskaičiuokite pelną po metų su 5% palūkanomis nuo 1000 €
metines_palukanos = 0.05
pradine_suma = 1000

palukanu_pelnas = pradine_suma *  metines_palukanos

print("Pelnas po metu:", palukanu_pelnas, "€")
# Out:
# Pelnas po metu: 50.0 €

# %%
## 7.Uzduotis.Apskaičiuokite pažymių [7, 8, 9] vidurkį.
pirmas_pazymys = 7
antras_pazymys = 8
trecias_pazymys = 9

pazymiu_vidurkis = (pirmas_pazymys+antras_pazymys+trecias_pazymys) /3

print("Pazymiu vidurkis:",pazymiu_vidurkis)
# Out:
# Pazymiu vidurkis: 8.0

# %%
## 8. Uzduotis. Apskaičiuokite, kiek procentų liko negrąžintos paskolos (1000 € – 350 € grąžinta).

visa_paskola = 1000
grazinta = 350

liko = visa_paskola - grazinta
liko_procentais = (liko/visa_paskola)* 100

print("Negrazintos paskolos dalis procentais:", liko_procentais, "%")
# Out:
# Negrazintos paskolos dalis procentais: 65.0 %

# %%
## 9. Uzdavinys. Apskaičiuokite trikampio plotą (pagrindas 6, aukštis 4).

trikampio_pagrindas = 6
trikampio_aukstis = 4

trikampio_plotas = (trikampio_pagrindas * trikampio_aukstis) /2
print("Trikampio plotas:",trikampio_plotas)
# Out:
# Trikampio plotas: 12.0

# %%
## 10. Uzduotis.  Apskaičiuokite bendrą dviejų prekių (3.50 € ir 4.20 €) kainą.

pirmos_prekes_kaina = 3.50
antros_prekes_kaina = 4.20

bendra_prekiu_kaina = pirmos_prekes_kaina + antros_prekes_kaina

print("Bendra dvieju prekiu kaina:", bendra_prekiu_kaina,"€")
# Out:
# Bendra dvieju prekiu kaina: 7.7 €

# %%
## 2 dalis. Teksto (string) metodai
## 11.Uzduotis.Išveskite žodį didžiosiomis raidėmis.

zodis = "python"
print(zodis.upper())
# Out:
# PYTHON

# %%
## 12. Uzduotis.  Išveskite sakinį mažosiomis raidėmis.

sakinys = "As einu grybauti!"
print(sakinys.lower())
# Out:
# as einu grybauti!

# %%
## 13. Uzduotis. Suskaičiuokite simbolių kiekį varde

name = "Rasa"
simboliu_kiekis = len(name)

print("Vardo simboliu kiekis:", simboliu_kiekis)
# Out:
# Vardo simboliu kiekis: 4

# %%
## 14.  Uzduotis. Padalinkite sakinį į žodžius ir parodykite pirmą žodį.

sakinys = "Saule sviecia labai stipriai"
zodziai = sakinys.split()

print("Pirmas zodis:", zodziai[0])
# Out:
# Pirmas zodis: Saule

# %%
## 15. Uzduotis.  Sujunkite du žodžius į vieną su tarpu
zodis1 = "Labas"
zodis2 = "pasauli"

sakinys = zodis1 +" " +zodis2
print(sakinys)
# Out:
# Labas pasauli

# %%
## 16. Uzduotis.  Sukurkite el. pašto adresą iš vardo ir pavardės
name = "Rasa"
pavarde = "Langard"

el_pastas = name.lower() +"." + pavarde.lower() +"@gmail.com"
print("EL.Pasto adresas:", el_pastas)
# Out:
# EL.Pasto adresas: rasa.langard@gmail.com

# %%
## 17. uzduotis.  Patikrinkite, ar žodyje yra raidė „a“.
zodis = "saulegraza"  

if "a" in zodis:
    print("Zodyje yra raide 'a'") 
else:
    
    print("Zodyje nera raides 'a'")
# Out:
# Zodyje yra raide 'a'

# %%
## 18. Uzduotis.  Pakeiskite visus simbolius „a“ į „*“.

tekstas = "programavimas"

naujas_tekstas = tekstas.replace("a","*")
print(naujas_tekstas)
# Out:
# progr*m*vim*s

# %%
## 19. Uzduotis. Išskirkite metus, mėnesį ir dieną iš datos „2025-06-01“

data = "2025-06-01"

dalys = data.split("-")

metai = dalys[0]
menuo = dalys[1]
diena = dalys[2]

print("Metai:", metai)
print("Mėnuo:", menuo)
print("Diena:", diena)
# Out:
# Metai: 2025
# Mėnuo: 06
# Diena: 01

# %%
## 20.Uzdavinys.  Išveskite pirmą ir paskutinį simbolį iš vardo.

name = "Jonas" 
pirmas = name[0]
antras = name [-1]

print("Pirmas simbolis", pirmas)
print("Paskutinis simbolis:", antras)
# Out:
# Pirmas simbolis J
# Paskutinis simbolis: s

# %%
## 3 Dalis Salygops su If/else
##21. Uzduotis. . Patikrinkite, ar skaičius yra teigiamas, neigiamas ar nulis.

skaicius = 6

if skaicius > 0:
    print("Skaicius yra teigiamas")
elif skaicius < 0:
    print("Skaicius yra neigiamas")
else:
    print("Skaicius yra nulis")
# Out:
# Skaicius yra teigiamas

# %%
## 22. Uzduotis. Įveskite amžių ir nustatykite, ar asmuo pilnametis.

amzius = 22

if amzius <= 18:
     print("Asmuo yra nepilnametis")
else:
    print("Asmuo yra pilnametis")
# Out:
# Asmuo yra pilnametis

# %%
## 23.Uzduotis. Patikrinkite, ar skaičius yra lyginis ar nelyginis.

skaicius = 5

if skaicius % 2 == 0:
    print("Skaicius yra lyginis")
else:
    print("Skaicius yra nelyginis")
# Out:
# Skaicius yra nelyginis

# %%
##24. Uzduotis. Įveskite vardą – jei „admin“, pasisveikinkite kaip su administratoriumi.

name = input("Iveskite varda:")

if name.lower() == "admin":
    print("Sveiki, administratoriau!")
else:
    print("Sveiki,",name)
# Out:
# Sveiki, rasa

# %%
##25. Uzduotis. Įveskite temperatūrą: jei >25 – „karšta“, tarp 10–25 – „normali“, kitaip – „šalta“

temperatura = float(input("Iveskite temperatura:"))

if temperatura > 25:
    print("Karsta")
elif 10 <= temperatura <= 25:
    print("Normali")
else:
    print("Salta")
# Out:
# Salta
