# %%
my_list = [1,2,3]

# %%
my_list = ['A string',23,100.232,'o']

# %%
my_list = ['one','two','three',4,5]

# %%
# make a list double
my_list * 30
# Out:
# ['one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
#  4,
#  5,
#  'one',
#  'two',
#  'three',
# ...

# %%
# creat a new list 
list1 = [1,2,3]

# %%
# Append
list1.append("append me!")

# %%
# show
list1
# Out:
# [1, 2, 3, 'append me!']

# %%
# pop off the 0 indexed item
list1.pop(-2)
# Out:
# 3

# %%
# assign the popped element

# %%
new_list =['a','e','x','b,'c]

# %%
# Let's make three lists
lst_1=[1,2,3]
lst_2=[4,5,6]
lst_3=[7,8,9]
 
# Make a list of lists to form a matrix
matrix = [lst_1,lst_2,lst_3]

# %%
#show 
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#grab first item in matrix object
matrix[0]
# Out:
# [1, 2, 3]

# %%
vaisiai = ["obuolys", "bananas", "kriause"]
print(vaisiai)
# Out:
# ['obuolys', 'bananas', 'kriause']

# %%
# Make a dictionary with {} and : to signify a key and a value
my_dict = {'key1':'value1','key2':'value2'}

# %%
asmuo = {   #susikuriame zodyna
    "vardas": "Jonas",
    "amzius": 30,
    "miestas": "Vilnius"
}
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 30, 'miestas': 'Vilnius'}

# %%
print(asmuo["vardas"])
print(asmuo.get("amzius"))
# Out:
# Jonas
# 30

# %%
asmuo["amzius"] = 31
asmuo["el_pastas"] = "jonas@example.com"
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 31, 'miestas': 'Vilnius', 'el_pastas': 'jonas@example.com'}

# %%
print(asmuo.keys())
print(asmuo.values())
print(asmuo.items())
# Out:
# dict_keys(['vardas', 'amzius', 'miestas', 'el_pastas'])
# dict_values(['Jonas', 31, 'Vilnius', 'jonas@example.com'])
# dict_items([('vardas', 'Jonas'), ('amzius', 31), ('miestas', 'Vilnius'), ('el_pastas', 'jonas@example.com')])

# %%
asmuo.pop("miestas") #rakto pasalinimas
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 31, 'el_pastas': 'jonas@example.com'}

# %%
print(len(asmuo)) #elementu skaicius
# Out:
# 3

# %%
asmuo.clear() # isvalyti zodyna
print(asmuo)
# Out:
# {}

# %%
ciklai
